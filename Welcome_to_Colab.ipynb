# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanakunder/Pythonnbasics/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")    #Hello word printing
# Out:
# Hello, World!

# %%
print ("my name is sumana")
# Out:
# my name is sumana

# %%
name = "Sumana"    #Variables
age = 25
height = 5.4

print(name)
print(age)
print(height)
# Out:
# Sumana
# 25
# 5.4

# %%
name = "j"                            #Variables
age = 2
height = 5.4

print(name)
print(age)
print(height)
# Out:
# j
# 2
# 5.4

# %%
course = "Python"

# %%
a = 10                 #Basic Operations
b = 3

print(a + b)   # Addition
print(a - b)   # Subtraction
print(a * b)   # Multiplication
print(a / b)   # Division
print(a % b)   # Remainder
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1

# %%
name = input("Enter your name: ")                     #Taking User Input
print("Hello", name)
# Out:
# Enter your name: sumana
# Hello sumana

# %%
age = int(input("Enter your age: "))                 #Input is always a string, so for numbers:
print(age + 1)
# Out:
# Enter your age: 27
# 28

# %%
a=2                                                 #sum
b=2
sum=a+b
print(sum)
# Out:
# 4

# %%
a=-2                                                     #if and elif ,else
if a<0:
  print("positive")
elif a>1:
  print("error")
else:
  print("negative")
# Out:
# positive

# %%
a=-2                                         # more than 2 if is nested
if a<0:
  print("positive")
if a<0:
  print("positive")
elif a>1:
  print("error")
else:
  print("negative")
# Out:
# positive
# positive

# %%
for e in range(5):                            #for
  print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
i = 1                                   #while
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5):                                              #continue
    if i % 2 == 0:
        print(f"Skipping even number: {i}")
        continue  # Skip the rest of the code in this iteration
    print(f"Processing odd number: {i}")

print("Loop finished.")
# Out:
# Skipping even number: 0
# Processing odd number: 1
# Skipping even number: 2
# Processing odd number: 3
# Skipping even number: 4
# Loop finished.

# %%
for i in range(5):                              #break
    if i==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
subjects = ["Math", "AI", "Python"]                   #list

print(subjects)
print(subjects[0])
print(subjects[0:1])
subjects.append("Data Science")
print(subjects)
subjects.insert(1, 'ML')
print(subjects)
# Out:
# ['Math', 'AI', 'Python']
# Math
# ['Math']
# ['Math', 'AI', 'Python', 'Data Science']
# ['Math', 'ML', 'AI', 'Python', 'Data Science']

# %%
text = "Python"               #string slicing
print(text[0:4])   # Pyth
print(text[2:])    # thon
print(text[:3])    # Pyt
# Out:
# Pyth
# thon
# Pyt

# %%
text = "datascience"            #string indexing
print(text[0])
print(text[-2])
# Out:
# d
# c

# %%
msg = " hello python "             # String Methods

print(msg.upper())
print(msg.lower())
print(msg.strip())
print(msg.replace("python", "AI"))
print(msg.split())
# Out:
#  HELLO PYTHON
#  hello python
# hello python
#  hello AI
# ['hello', 'python']

# %%
a = "10"                           # Type Conversion
b = int(a)

print(b + 5)
# Out:
# 15

# %%
int()
float()
str()
# Out:
# ''

# %%
for i in range(1, 4):
    for j in range(1, 4):
        print(i, j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %%
for i in range(1, 6):                            # simple pattern program
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1, 4):                            # simple pattern program
    print("6" * i)
# Out:
# 6
# 66
# 666
